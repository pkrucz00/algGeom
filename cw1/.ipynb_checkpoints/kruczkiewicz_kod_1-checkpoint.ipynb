# %% [markdown]
# # Algorytmy geometryczne, ćwiczenie 1
# ## Cel ćwiczenia
# Ćwiczenie  wprowadzające  w  zagadnienia  geometrii  obliczeniowej  –  implementacja  podstawowych
# predykatów geometrycznych, przeprowadzenie testów, wizualizacja i opracowanie wyników.

# %% [markdown]
# ### Konfiguracja

# %%
# Narzędzie jest oparte o kilka zewnętrznych bibliotek, które potrzebujemy najpierw zaimportować.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections as mcoll
import matplotlib.colors as mcolors
from matplotlib.widgets import Button
import json as js

# Parametr określający jak blisko (w odsetku całego widocznego zakresu) punktu początkowego 
# wielokąta musimy kliknąć, aby go zamknąć.
TOLERANCE = 0.15

def dist(point1, point2):
    return np.sqrt(np.power(point1[0] - point2[0], 2) + np.power(point1[1] - point2[1], 2))

# Klasa ta trzyma obecny stan wykresu oraz posiada metody, które mają zostać wykonane
# po naciśnięciu przycisków.
class _Button_callback(object):
    def __init__(self, scenes):
        self.i = 0
        self.scenes = scenes
        self.adding_points = False
        self.added_points = []
        self.adding_lines = False
        self.added_lines = []
        self.adding_rects = False
        self.added_rects = []

    def set_axes(self, ax):
        self.ax = ax
        
    # Metoda ta obsługuje logikę przejścia do następnej sceny.
    def next(self, event):
        self.i = (self.i + 1) % len(self.scenes)
        self.draw(autoscaling = True)

    # Metoda ta obsługuje logikę powrotu do poprzedniej sceny.
    def prev(self, event):
        self.i = (self.i - 1) % len(self.scenes)
        self.draw(autoscaling = True)
        
    # Metoda ta aktywuje funkcję rysowania punktów wyłączając równocześnie rysowanie 
    # odcinków i wielokątów.
    def add_point(self, event):
        self.adding_points = not self.adding_points
        self.new_line_point = None
        if self.adding_points:
            self.adding_lines = False
            self.adding_rects = False
            self.added_points.append(PointsCollection([]))
            
    # Metoda ta aktywuje funkcję rysowania odcinków wyłączając równocześnie
    # rysowanie punktów i wielokątów.     
    def add_line(self, event):   
        self.adding_lines = not self.adding_lines
        self.new_line_point = None
        if self.adding_lines:
            self.adding_points = False
            self.adding_rects = False
            self.added_lines.append(LinesCollection([]))

    # Metoda ta aktywuje funkcję rysowania wielokątów wyłączając równocześnie
    # rysowanie punktów i odcinków.
    def add_rect(self, event):
        self.adding_rects = not self.adding_rects
        self.new_line_point = None
        if self.adding_rects:
            self.adding_points = False
            self.adding_lines = False
            self.new_rect()
    
    def new_rect(self):
        self.added_rects.append(LinesCollection([]))
        self.rect_points = []
        
    # Metoda odpowiedzialna za właściwą logikę rysowania nowych elementów. W
    # zależności od włączonego trybu dodaje nowe punkty, początek, koniec odcinka
    # lub poszczególne wierzchołki wielokąta. Istnieje ciekawa logika sprawdzania
    # czy dany punkt jest domykający dla danego wielokąta. Polega ona na tym, że
    # sprawdzamy czy odległość nowego punktu od początkowego jest większa od
    # średniej długości zakresu pomnożonej razy parametr TOLERANCE.   
    def on_click(self, event):
        if event.inaxes != self.ax:
            return
        new_point = (event.xdata, event.ydata)
        if self.adding_points:
            self.added_points[-1].add_points([new_point])
            self.draw(autoscaling = False)
        elif self.adding_lines:
            if self.new_line_point is not None:
                self.added_lines[-1].add([self.new_line_point, new_point])
                self.new_line_point = None
                self.draw(autoscaling = False)
            else:
                self.new_line_point = new_point
        elif self.adding_rects:
            if len(self.rect_points) == 0:
                self.rect_points.append(new_point)
            elif len(self.rect_points) == 1:
                self.added_rects[-1].add([self.rect_points[-1], new_point])
                self.rect_points.append(new_point)
                self.draw(autoscaling = False)
            elif len(self.rect_points) > 1:
                if dist(self.rect_points[0], new_point) < (np.mean([self.ax.get_xlim(), self.ax.get_ylim()])*TOLERANCE):
                    self.added_rects[-1].add([self.rect_points[-1], self.rect_points[0]])
                    self.new_rect()
                else:    
                    self.added_rects[-1].add([self.rect_points[-1], new_point])
                    self.rect_points.append(new_point)
                self.draw(autoscaling = False)
    
    # Metoda odpowiedzialna za narysowanie całego wykresu. Warto zauważyć,
    # że zaczyna się ona od wyczyszczenia jego wcześniejszego stanu. Istnieje w
    # niej nietrywialna logika zarządzania zakresem wykresu, tak żeby, w zależności
    # od ustawionego parametru autoscaling, uniknąć sytuacji, kiedy dodawanie
    # nowych punktów przy brzegu obecnie widzianego zakresu powoduje niekorzystne
    # przeskalowanie.
    def draw(self, autoscaling = True):
        if not autoscaling:
            xlim = self.ax.get_xlim()
            ylim = self.ax.get_ylim()
        self.ax.clear()
        for collection in (self.scenes[self.i].points + self.added_points):
            if len(collection.points) > 0:
                self.ax.scatter(*zip(*(np.array(collection.points))), **collection.kwargs)
        for collection in (self.scenes[self.i].lines + self.added_lines + self.added_rects):
            self.ax.add_collection(collection.get_collection())
        self.ax.autoscale(autoscaling)
        if not autoscaling:
            self.ax.set_xlim(xlim)
            self.ax.set_ylim(ylim)
        plt.draw()

# %% [markdown]
# ### Interfejsy
#
# [Dostępne kolory](https://matplotlib.org/3.1.1/gallery/color/named_colors.html)
#
# [Dostępne znaczniki punktów](https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers)

# %%
# Klasa Scene odpowiada za przechowywanie elementów, które mają być
# wyświetlane równocześnie. Konkretnie jest to lista PointsCollection i
# LinesCollection.
class Scene:
    def __init__(self, points=[], lines=[]):
        self.points=points
        self.lines=lines

# Klasa PointsCollection gromadzi w sobie punkty jednego typu, a więc takie,
# które zostaną narysowane w takim samym kolorze i stylu. W konstruktorze
# przyjmuje listę punktów rozumianych jako pary współrzędnych (x, y). Parametr
# kwargs jest przekazywany do wywołania funkcji z biblioteki MatPlotLib przez
# co użytkownik może podawać wszystkie parametry tam zaproponowane.        
class PointsCollection:
    def __init__(self, points, **kwargs):
        self.points = points
        self.kwargs = kwargs
    
    def add_points(self, points):
        self.points = self.points + points

# Klasa LinesCollection podobnie jak jej punktowy odpowiednik gromadzi
# odcinki tego samego typu. Tworząc ją należy podać listę linii, gdzie każda
# z nich jest dwuelementową listą punktów – par (x, y). Parametr kwargs jest
# przekazywany do wywołania funkcji z biblioteki MatPlotLib przez co użytkownik
# może podawać wszystkie parametry tam zaproponowane.
class LinesCollection:
    def __init__(self, lines, **kwargs):
        self.lines = lines
        self.kwargs = kwargs
        
    def add(self, line):
        self.lines.append(line)
        
    def get_collection(self):
        return mcoll.LineCollection(self.lines, **self.kwargs)

# Klasa Plot jest najważniejszą klasą w całym programie, ponieważ agreguje
# wszystkie przygotowane sceny, odpowiada za stworzenie wykresu i przechowuje
# referencje na przyciski, dzięki czemu nie będą one skasowane podczas tzw.
# garbage collectingu.
class Plot:
    def __init__(self, scenes = [Scene()], points = [], lines = [], json = None):
        if json is None:
            self.scenes = scenes
            if points or lines:
                self.scenes[0].points = points
                self.scenes[0].lines = lines
        else:
            self.scenes = [Scene([PointsCollection(pointsCol) for pointsCol in scene["points"]], 
                                 [LinesCollection(linesCol) for linesCol in scene["lines"]]) 
                           for scene in js.loads(json)]
    
    # Ta metoda ma szczególne znaczenie, ponieważ konfiguruje przyciski i
    # wykonuje tym samym dość skomplikowaną logikę. Zauważmy, że konfigurując każdy
    # przycisk podajemy referencję na metodę obiektu _Button_callback, która
    # zostanie wykonana w momencie naciśnięcia.
    def __configure_buttons(self):
        plt.subplots_adjust(bottom=0.2)
        ax_prev = plt.axes([0.6, 0.05, 0.15, 0.075])
        ax_next = plt.axes([0.76, 0.05, 0.15, 0.075])
        ax_add_point = plt.axes([0.44, 0.05, 0.15, 0.075])
        ax_add_line = plt.axes([0.28, 0.05, 0.15, 0.075])
        ax_add_rect = plt.axes([0.12, 0.05, 0.15, 0.075])
        b_next = Button(ax_next, 'Następny')
        b_next.on_clicked(self.callback.next)
        b_prev = Button(ax_prev, 'Poprzedni')
        b_prev.on_clicked(self.callback.prev)
        b_add_point = Button(ax_add_point, 'Dodaj punkt')
        b_add_point.on_clicked(self.callback.add_point)
        b_add_line = Button(ax_add_line, 'Dodaj linię')
        b_add_line.on_clicked(self.callback.add_line)
        b_add_rect = Button(ax_add_rect, 'Dodaj figurę')
        b_add_rect.on_clicked(self.callback.add_rect)
        return [b_prev, b_next, b_add_point, b_add_line, b_add_rect]
    
    def add_scene(self, scene):
        self.scenes.append(scene)
    
    def add_scenes(self, scenes):
        self.scenes = self.scenes + scenes

    # Metoda toJson() odpowiada za zapisanie stanu obiektu do ciągu znaków w
    # formacie JSON.
    def toJson(self):
        return js.dumps([{"points": [np.array(pointCol.points).tolist() for pointCol in scene.points], 
                          "lines":[linesCol.lines for linesCol in scene.lines]} 
                         for scene in self.scenes])    
    
    # Metoda ta zwraca punkty dodane w trakcie rysowania.
    def get_added_points(self):
        if self.callback:
            return self.callback.added_points
        else:
            return None
    
    # Metoda ta zwraca odcinki dodane w trakcie rysowania.
    def get_added_lines(self):
        if self.callback:
            return self.callback.added_lines
        else:
            return None
        
    # Metoda ta zwraca wielokąty dodane w trakcie rysowania.
    def get_added_figure(self):
        if self.callback:
            return self.callback.added_rects
        else:
            return None
    
    # Metoda ta zwraca punkty, odcinki i wielokąty dodane w trakcie rysowania
    # jako scenę.
    def get_added_elements(self):
        if self.callback:
            return Scene(self.callback.added_points, self.callback.added_lines+self.callback.added_rects)
        else:
            return None
    
    # Główna metoda inicjalizująca wyświetlanie wykresu.
    def draw(self):
        plt.close()
        fig = plt.figure()
        self.callback = _Button_callback(self.scenes)
        self.widgets = self.__configure_buttons()
        ax = plt.axes(autoscale_on = False)
        self.callback.set_axes(ax)
        fig.canvas.mpl_connect('button_press_event', self.callback.on_click)
        plt.show()
        self.callback.draw()

# %% [markdown]
# ## Rozwiązanie
# ### Funkcje generujące punkty

# %%
from random import uniform
from math import cos, sin, pi


def pointsInInterval(s, t, n):  # s, t - minimal and maximal value of coordinate, n - number of points
    return [(uniform(s, t), uniform(s, t)) for _ in range(n)]


def pointsInCircle(c, r, n):  # c - center, r - radius, n - number of points
    result = []
    for _ in range(n):
        fi = uniform(0, 2 * pi)
        x = c[0] + r*cos(fi)
        y = c[1] + r*sin(fi)
        result.append((x, y))
    return result


def pointsInLine(a, b, s, t, n):  # a, b - points, s,t - range, n - number of points
    def findLineParams(a, b):  # find A and B in y = Ax + B
        (x1, y1), (x2, y2) = a, b
        A = (y1 - y2) / (x1 - x2)
        B = y1 - A * x1
        return A, B

    if a[0] == b[0]:    #if the given points create a vertical line
        return [(a[0], uniform(min(a[1], b[1]), max(a[1], b[1]))) for _ in range(n)]

    result = []
    A, B = findLineParams(a, b)
    for _ in range(n):
        x = uniform(s, t)
        y = A * x + B
        result.append((x, y))
    return result

# %% [markdown]
# Funkcja `pointsInIntervall` losuje daną liczbę punktów w danym zakresie (zapełnia nimi kwadrat)
#
# Funkcja `pointsInCircle` losuje n punktów na okręgu o danym środku i promieniu. W tym celu używana jest funkcja sinus i cosinus, dzięki którym rozkład punktów jest równomierny.
#
# Funkcja `pointsInLine` przyjmuje 2 punkty (w postaci tupli), zakres i losuje n punktów. Funkcja losuje współrzędną x i wylicza na podstawie parametrów A i B (obliczonych za pomocą funkcji pomocniczej `findLineParams`) współrzędną y.

# %% [markdown]
# ### Losowanie punktów i przygotowanie doświadczenia

# %%
# %matplotlib notebook

interval = [(-1., 0.), (1., 0.1)]     

pointSets = [pointsInInterval(-10 ** 3, 10 ** 3, 10 ** 5),
             pointsInInterval(-10 ** 14, 10 ** 14, 10 ** 5),
             pointsInCircle((0,0), 100, 1000),
             pointsInLine(interval[0], interval[1], -1000, 1000, 1000)]

epsilons = [0, 10**(-14), 10**(-12), 10**(-10)]
colors = ['red', 'blue', 'khaki']

# %% [markdown]
# Powyżej zdefiniowano kilka zmiennych globalnych:
#
# `interval` to punkty z odcinka ab danego w ćwiczeniu. <br>
# `pointSets` to zbiory punktów dane w ćwiczeniu <br><br>
# Listy pomocnicze:<br>
# `epsilons` - dokładność przy przyporządkowywaniu punktów do danej grupy (współliniowych, po lewej, po prawej od odcinka)<br>
# `colors` - kolory dla poszczególnych grup

# %% [markdown]
# ### Wizualizacja zbiorów punktów

# %%
scenes = [Scene([PointsCollection(pointSet)]) for pointSet in pointSets]
plot = Plot(scenes = scenes)
plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Funkcja dzieląca wylosowane punkty

# %%
def divideWRTinterval(interval, points, eps, detFunc):   #eps - epsilon, detFunc - function that computes the determinant
    a, b = interval
    result = {"Left":[], "Right": [], "Collinear": []}  # sets for collinear, left and right WRT interval
    for c in points:
        det = detFunc(a, b, c)   # computing the determinant of given interval and the point c
        if det < -eps:           # c is clockwise to the interval - it's on its right 
            result["Right"].append(c)
        elif det > eps:          # c is counterclockwise to the interval - it's on its left
            result["Left"].append(c)
        else:                    # c is within the "epsilon range" - collinear
            result["Collinear"].append(c)

    return result

# %% [markdown]
# Funkcja `divideWRTInterval` przyjmuje odcinek (w formie tupli), listę punktów, epsilon oraz funkcję wyliczającą wyznacznik. Funkcja dla każdego punktu sprawdza jego wyznacznik i na tej podstawie przypisuje go do odpowiedniej listy w tablicy `result`

# %%
def showStats(results, epsilons):
    def prepForPrinting(results, keys):
        res = []
        for key in keys:
            newTable = []
            for result in results:
                newTable.append(len(result[key]))
            res.append(newTable)
        return res
            
    keys = list(results[0].keys())
    tabToPrint = prepForPrinting(results, keys)

    print("         ", end='')  # tab for clarity
    for eps in epsilons:
        print("{:.0e}".format(eps), end=' ')   #scientific notation
    print()
    
    for i, key in enumerate(keys):
        print("%8s" % key, end='')
        for res in tabToPrint[i]:
            print("%6d" % res, end='')
        print()

# %% [markdown]
# Powyższa funkcja rysuje tabelkę przypisującą danej funkcji liczącej wyznacznik wyniki przyporządkowania dla danego zbioru.

# %%
def resultsForGivenDetFuncAndPointSet(detFunc, pSet, marker='.'):
    results = [divideWRTinterval(interval, pSet , eps, detFunc) for eps in epsilons]
    showStats(results, epsilons)
 
    scenes = [Scene([PointsCollection(res[k], color=colors[i], marker=marker) 
                     for i, k in enumerate(res.keys())])
              for res in results]

    plot = Plot(scenes=scenes)
    return plot

# %% [markdown]
# Funkcja podaje statystyki i rysuje wykres dla danej funkcji liczącej wyznacznik oraz danego zbioru punktów

# %% [markdown]
# ## Badanie wyznaczników
# ### Wyznaczniki własne
# #### Wyznacznik z macierzy 2x2

# %%
def det2x2(a,b,c):
    return (a[0]-c[0])*(b[1]-c[1]) - (a[1]-c[1])*(b[0]-c[0])

# %% [markdown]
# #### Zbiór pierwszy

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2, pointSets[0])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49813 49813 49813 49813
#    Right 50187 50187 50187 50187
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór drugi

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2, pointSets[1])
plot.draw()

result = divideWRTinterval(interval, pointSets[1], 0, det2x2)   #additional - determining which points are falsely collinear
print('Falsely collinear:')
for point in result["Collinear"]:
    print(point, abs(point[1]-point[0])) #showing the point and difference between its coordinates (the latter is around 10^14)
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49877 49877 49877 49877
#    Right 50118 50118 50118 50118
# Collinear     5     5     5     5
# <img src="data:image/png;base64,..." width="640">
# Falsely collinear:
# (67939920356158.5, 3400899777230.2656) 64539020578928.234
# (-68412111289203.414, -3432129471130.7344) 64979981818072.68
# (67694444976111.375, 3373542116554.2344) 64320902859557.14
# (-67346578667100.234, -3382761512718.5625) 63963817154381.67
# (-69201695858689.38, -3466678714681.672) 65735017144007.71

# %% [markdown]
# #### Zbiór trzeci

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2, pointSets[2])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   527   527   527   527
#    Right   473   473   473   473
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór czwarty

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2, pointSets[3], marker='.')
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   165   154    86     0
#    Right   134   127    74     0
# Collinear   701   719   840  1000
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Wyznacznik 3x3

# %%
def det3x3(a,b,c):
    s1 = a[0]*b[1] + b[0]*c[1] + c[0]*a[1]
    s2 = a[1]*b[0] + b[1]*c[0] + c[1]*a[0]
    return s1 - s2

# %% [markdown]
# #### Zbiór pierwszy

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3, pointSets[0])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49813 49813 49813 49813
#    Right 50187 50187 50187 50187
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór drugi

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3, pointSets[1])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49878 49878 49878 49878
#    Right 50122 50122 50122 50122
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór trzeci

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3, pointSets[2])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   527   527   527   527
#    Right   473   473   473   473
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór czwarty

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3, pointSets[3], marker='.')
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   179     0     0     0
#    Right   429     0     0     0
# Collinear   392  1000  1000  1000
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Wyznaczniki biblioteki Numpy
# #### Wyznacznik 2x2 Numpy

# %%
def det2x2withNp(a,b,c):
    auxArr = [a, b]
    arr = np.array([[v[i]-c[i] for i in range(2)] for v in auxArr])
    return np.linalg.det(arr)

# %% [markdown]
# #### Zbiór pierwszy

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2withNp, pointSets[0])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49813 49813 49813 49813
#    Right 50187 50187 50187 50187
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór drugi

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2withNp, pointSets[1])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49878 49878 49878 49878
#    Right 50122 50122 50122 50122
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór trzeci

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2withNp, pointSets[2])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   527   527   527   527
#    Right   473   473   473   473
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór czwarty

# %%
plot = resultsForGivenDetFuncAndPointSet(det2x2withNp, pointSets[3], marker='.')
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   507   464   133     0
#    Right   493   442   137     0
# Collinear     0    94   730  1000
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Wyznacznik 3x3 Numpy

# %%
def det3x3withNp(a,b,c):
    auxArr = [a,b,c]
    arr = np.array([[v[0], v[1], 1] for v in auxArr])
    return np.linalg.det(arr)

# %% [markdown]
# #### Zbiór pierwszy

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3withNp, pointSets[0])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49813 49813 49813 49813
#    Right 50187 50187 50187 50187
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór drugi

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3withNp, pointSets[1])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left 49878 49878 49878 49878
#    Right 50122 50122 50122 50122
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór trzeci

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3withNp, pointSets[2])
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   527   527   527   527
#    Right   473   473   473   473
# Collinear     0     0     0     0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Zbiór czwarty

# %%
plot = resultsForGivenDetFuncAndPointSet(det3x3withNp, pointSets[3], marker='.')
plot.draw()
# Out:
#          0e+00 1e-14 1e-12 1e-10
#     Left   455    14     0     0
#    Right   545   112     0     0
# Collinear     0   874  1000  1000
# <img src="data:image/png;base64,..." width="640">
